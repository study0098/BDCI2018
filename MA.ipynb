# %%
 import pandas as pd
from tqdm import tqdm
import numpy as np
goodsSale = pd.read_csv('C:/Users/xyttttt/Desktop/alldata/goodsale.csv',encoding='utf8',low_memory=False)
submit = pd.read_csv('C:/Users/xyttttt/Desktop/alldata/submit_example.csv',encoding='utf8',low_memory=False)

goodsNum = pd.DataFrame({'sku_id':submit['sku_id']})
goodsNum12 = pd.DataFrame({'sku_id':submit['sku_id']})
dates = []
for i in range(20171211,20171232):
    dates.append(i)
for i in range(20180101,20180132):
    dates.append(i)
for i in range(20180201,20180229):
    dates.append(i)
for i in range(20180301,20180318):
    dates.append(i)
for date in dates:
    sale12 = goodsSale[(goodsSale.data_date==date)]
    df = pd.DataFrame({str(date):sale12.goods_num,'sku_id':sale12.sku_id})
    goodsNum12 = pd.merge(goodsNum12,df,on='sku_id',how='left')
plandate = []
for date in range(20180206,20180213):
    plandate.append(str(date))
goodsNum12['9'] = pd.DataFrame(goodsNum12,columns=plandate).apply(lambda x:x.sum(),axis=1)
plandate = []
for date in range(20180213,20180220):
    plandate.append(str(date))
goodsNum12['10'] = pd.DataFrame(goodsNum12,columns=plandate).apply(lambda x:x.sum(),axis=1)
plandate = []
for date in range(20180220,20180227):
    plandate.append(str(date))
goodsNum12['11'] = pd.DataFrame(goodsNum12,columns=plandate).apply(lambda x:x.sum(),axis=1)
plandate = []
for date in range(20180227,20180229):
    plandate.append(str(date))
for date in range(20180301,20180306):
    plandate.append(str(date))
goodsNum12['12'] = pd.DataFrame(goodsNum12,columns=plandate).apply(lambda x:x.sum(),axis=1)
plandate = []
for date in range(20180306,20180313):
    plandate.append(str(date))
goodsNum12['13'] = pd.DataFrame(goodsNum12,columns=plandate).apply(lambda x:x.sum(),axis=1)
plandate = []
for date in range(20180313,20180317):
    plandate.append(str(date))
goodsNum12['14'] = pd.DataFrame(goodsNum12,columns=plandate).apply(lambda x:x.sum(),axis=1)
#goodsNum12.to_csv('C:/Users/xyttttt/Desktop/alldata/plan.csv',index = False)

print(1)
# Out:
# 1

# %%
plandate = []
for date in range(20171211,20171218):
    plandate.append(str(date))
goodsNum12['1'] = pd.DataFrame(goodsNum12,columns=plandate).apply(lambda x:x.sum(),axis=1)
plandate = []
for date in range(20171218,20171225):
    plandate.append(str(date))
goodsNum12['2'] = pd.DataFrame(goodsNum12,columns=plandate).apply(lambda x:x.sum(),axis=1)
plandate = []
for date in range(20171225,20171232):
    plandate.append(str(date))
goodsNum12['3'] = pd.DataFrame(goodsNum12,columns=plandate).apply(lambda x:x.sum(),axis=1)
plandate = []
for date in range(20180101,20180108):
    plandate.append(str(date))
goodsNum12['4'] = pd.DataFrame(goodsNum12,columns=plandate).apply(lambda x:x.sum(),axis=1)
plandate = []
for date in range(20180108,20180115):
    plandate.append(str(date))
goodsNum12['5'] = pd.DataFrame(goodsNum12,columns=plandate).apply(lambda x:x.sum(),axis=1)
plandate = []
for date in range(20180115,20180122):
    plandate.append(str(date))
goodsNum12['6'] = pd.DataFrame(goodsNum12,columns=plandate).apply(lambda x:x.sum(),axis=1)
plandate = []
for date in range(20180122,20180129):
    plandate.append(str(date))
goodsNum12['7'] = pd.DataFrame(goodsNum12,columns=plandate).apply(lambda x:x.sum(),axis=1)
plandate = []
for date in range(20180129,20180206):
    plandate.append(str(date))
goodsNum12['8'] = pd.DataFrame(goodsNum12,columns=plandate).apply(lambda x:x.sum(),axis=1)
import pandas as pd
from tqdm import tqdm
import numpy as np
from numpy import random as nr
import matplotlib as mpl
import matplotlib.pyplot as plt
from IPython.core.pylabtools import figsize
df=pd.read_csv('C:/Users/xyttttt/Desktop/result_chh_899.csv',encoding='utf8',low_memory=False)
x=range(104510)

plt.rcParams['figure.dpi'] = 300
plt.scatter(x,df.week1,s=0.1)
plandate = []
for date in range(20171229,20180104):
    plandate.append(str(date))
goodsNum12['plan0'] = pd.DataFrame(goodsNum12,columns=plandate).apply(lambda x:x.sum(),axis=1)
plandate = []
for date in range(20180104,20180112):
    plandate.append(str(date))
goodsNum12['plan0'] = pd.DataFrame(goodsNum12,columns=plandate).apply(lambda x:x.sum(),axis=1)
plandate = []
for date in range(20180112,20180120):
    plandate.append(str(date))
goodsNum12['plan1'] = pd.DataFrame(goodsNum12,columns=plandate).apply(lambda x:x.sum(),axis=1)
plandate = []
for date in range(20180120,20180128):
    plandate.append(str(date))
goodsNum12['plan2'] = pd.DataFrame(goodsNum12,columns=plandate).apply(lambda x:x.sum(),axis=1)
plandate = []
for date in range(20180127,20180203):
    plandate.append(str(date))
goodsNum12['plan3'] = pd.DataFrame(goodsNum12,columns=plandate).apply(lambda x:x.sum(),axis=1)
plandate = []
for date in range(20180203,20180211):
    plandate.append(str(date))
goodsNum12['plan4'] = pd.DataFrame(goodsNum12,columns=plandate).apply(lambda x:x.sum(),axis=1)
plandate = []
for date in range(20180210,20180218):
    plandate.append(str(date))
goodsNum12['plan5'] = pd.DataFrame(goodsNum12,columns=plandate).apply(lambda x:x.sum(),axis=1)
plandate = []
for date in range(20180217,20180225):
    plandate.append(str(date))
goodsNum12['plan6'] = pd.DataFrame(goodsNum12,columns=plandate).apply(lambda x:x.sum(),axis=1)
plandate = []
for date in range(20180224,20180229):
    plandate.append(str(date))
for date in range(20180301,20180302):
    plandate.append(str(date))
goodsNum12['plan7'] = pd.DataFrame(goodsNum12,columns=plandate).apply(lambda x:x.sum(),axis=1)
plandate = []
for date in range(20180302,20180309):
    plandate.append(str(date))
goodsNum12['plan8'] = pd.DataFrame(goodsNum12,columns=plandate).apply(lambda x:x.sum(),axis=1)
plandate = []
for date in range(20180312,20180317):
    plandate.append(str(date))
goodsNum12['plan9'] = pd.DataFrame(goodsNum12,columns=plandate).apply(lambda x:x.sum(),axis=1)
goodsNum12.to_csv('C:/Users/xyttttt/Desktop/alldata/plan.csv',index = False)

# %%
import pandas as pd
from tqdm import tqdm
import numpy as np
from numpy import random as nr
import matplotlib as mpl
import matplotlib.pyplot as plt
from IPython.core.pylabtools import figsize
df=pd.read_csv('C:/Users/lenovo/Desktop/result_882.csv',encoding='utf8',low_memory=False)
x=range(104510)

plt.rcParams['figure.dpi'] = 300
plt.scatter(x,df.week1,s=0.1)

# %%
import pandas as pd
from tqdm import tqdm
import numpy as np
from numpy import random as nr
import matplotlib as mpl
import matplotlib.pyplot as plt
from IPython.core.pylabtools import figsize
df=pd.read_csv('C:/Users/xyttttt/Desktop/submit_rfr.csv',low_memory=False)
x=range(104510)
df1=df.loc[df['week1']>=100]
plt.rcParams['figure.dpi'] = 300
plt.scatter(x,df.week1,s=0.1)
plt.plot(df1.week1,marker='o')

# %%
########0918
goodsNum['week1'] = np.floor((goodsNum12['9']*0.2+goodsNum12['10']*0.15+goodsNum12['11']*0.02+goodsNum12['12']*0.03+goodsNum12['13']*0.2+goodsNum12['14']*0.4)).astype(int)
goodsNum['week2']=np.floor((goodsNum12['9']*0.2+goodsNum12['10']*0.15+goodsNum12['11']*0.02+goodsNum12['12']*0.03+goodsNum12['13']*0.2+goodsNum12['14']*0.4)).astype(int)
goodsNum['week3']=np.floor((goodsNum12['9']*0.2+goodsNum12['10']*0.15+goodsNum12['11']*0.02+goodsNum12['12']*0.03+goodsNum12['13']*0.2+goodsNum12['14']*0.4)).astype(int)
goodsNum['week4']=np.floor((goodsNum12['9']*0.2+goodsNum12['10']*0.15+goodsNum12['11']*0.02+goodsNum12['12']*0.03+goodsNum12['13']*0.2+goodsNum12['14']*0.4)).astype(int)
goodsNum['week5']=np.floor((goodsNum12['9']*0.2+goodsNum12['10']*0.15+goodsNum12['11']*0.02+goodsNum12['12']*0.03+goodsNum12['13']*0.2+goodsNum12['14']*0.4)).astype(int)
goodsNum.to_csv('C:/Users/xyttttt/Desktop/918t.csv',index = False)
goodsNum
# Out:
#           sku_id  week1  week2  week3  week4  week5
# 0       SKDtK67I      2      2      2      2      2
# 1       SKpLKkIS      0      0      0      0      0
# 2       SK2vQMpX     10     10     10     10     10
# 3       SKY0RuBE      2      2      2      2      2
# 4       SKvr2o3y      0      0      0      0      0
# 5       SK4VKk3b      0      0      0      0      0
# 6       SKDbZjmX      1      1      1      1      1
# 7       SK9wkGUJ      0      0      0      0      0
# 8       SKjQriLy      0      0      0      0      0
# 9       SKGy1eQD      2      2      2      2      2
# 10      SKd8KLXp      0      0      0      0      0
# 11      SK6ry4mi      0      0      0      0      0
# 12      SKOpvNGo      3      3      3      3      3
# 13      SKMF0WaA      0      0      0      0      0
# 14      SKdm0HJM      0      0      0      0      0
# 15      SKBkZXdJ      0      0      0      0      0
# 16      SKSbGnOU      1      1      1      1      1
# ...

# %%
import pandas as pd
from tqdm import tqdm
import numpy as np
from numpy import random as nr
import matplotlib as mpl
import matplotlib.pyplot as plt
from IPython.core.pylabtools import figsize
df=pd.read_csv('C:/Users/xyttttt/Desktop/confi.csv',low_memory=False)
df1=pd.read_csv('C:/Users/xyttttt/Desktop/alldata/0918.csv',low_memory=False)
x=range(104510)
df2=df.loc[df['week1']>=100]
df3=df1.loc[df1['week1']>=100]
plt.rcParams['figure.dpi'] = 300
plt.scatter(x,df.week1,s=0.1)
plt.plot(df2.week1,marker='.')
plt.plot(df3.week1,marker='.')

# %%
fileHead = 'C:/Users/xyttttt/Desktop/alldata'
goodsPromotePrice = pd.read_csv(fileHead+'/goods_promote_price.csv',encoding='utf8')
goodsSkuRelation = pd.read_csv(fileHead+'/goods_sku_relation.csv',encoding='utf8')
goodsDaily = pd.read_csv(fileHead+'/goodsdaily.csv',encoding='utf8')
goodsInfo = pd.read_csv(fileHead+'/goodsinfo.csv',encoding='utf8')
marketing = pd.read_csv(fileHead+'/marketing.csv',encoding='utf8')
allDataDate=[]
days = [31,28,31,30,31,30,31,31,30,31,30,31]
for y in [2017,2018]:
    for m in range(1,13):
        for d in range(1,days[m-1]+1):
            allDataDate.append(int(str(y)+('0'+str(m))[-2:]+('0'+str(d))[-2:]))
allDataDate = allDataDate[59:440]
allDate = {}
for date in allDataDate:
    allDate[date] = allDataDate.index(date)
allDate = pd.DataFrame({'data_date':list(allDate.keys()),'day_num':list(allDate.values())})
allDate['data_date'] = allDate['data_date'].astype('int')
allDate['day_num'] = allDate['day_num'].astype('int')

goodsDate = pd.DataFrame({'data_date':goodsDaily.data_date,'goods_id':goodsDaily.goods_id,'onsale_days':goodsDaily.onsale_days})
goodsDate = goodsDate.drop_duplicates('goods_id')
goodsDate = pd.merge(goodsDate, allDate, on='data_date',how='left')
goodsDate['market_day'] = goodsDate.day_num-goodsDate.onsale_days
goodsDate.loc[goodsDate.market_day<0,'market_day'] = 0
goodsDate = pd.merge(goodsDate, pd.DataFrame({'market_day':allDate.day_num,'market_date':allDate.data_date}),on='market_day',how='left')
goodsDate = pd.merge(goodsDate, goodsSkuRelation, on='goods_id',how='left')
goodsDate = goodsDate.drop(['data_date','day_num','market_day'],axis=1)

ddddffff = pd.merge(submit, goodsDate, on='sku_id',how='left')

# %%
import pandas as pd
from tqdm import tqdm
import numpy as np
from numpy import random as nr
import matplotlib as mpl
import matplotlib.pyplot as plt
from IPython.core.pylabtools import figsize
df=pd.read_csv('C:/Users/xyttttt/Desktop/alldata/0918.csv',low_memory=False)
df11=pd.read_csv('C:/Users/xyttttt/Desktop/result_other.csv',low_memory=False)
x=range(104510)
df1=df.loc[df['week1']>=100]
df112=df11.loc[df11['week1']>=100]
plt.rcParams['figure.dpi'] = 300
plt.scatter(x,df.week1,s=0.1)
plt.plot(df1.week1,marker='.')
plt.plot(df112.week1,marker='.')

# %% [markdown]
# goodsNum12

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from IPython.core.pylabtools import figsize
r,c=goodsNum12.shape
list1=[]
list2=range(14)
skuid=goodsNum12.iloc[2,0]
df3=goodsNum12.loc[goodsNum12['sku_id']==skuid]
for j in range(1,15):
    list1.append(df3[str(j)].item()) 
plt.scatter(list2,list1)

# %%
goodsNum12['1'].apply(lambda x:x==0)
# Out:
# 0          True
# 1          True
# 2         False
# 3         False
# 4         False
# 5          True
# 6          True
# 7         False
# 8          True
# 9         False
# 10         True
# 11         True
# 12        False
# 13         True
# 14        False
# 15         True
# 16        False
# 17         True
# 18         True
# 19         True
# 20        False
# 21         True
# 22         True
# 23         True
# 24        False
# 25         True
# 26         True
# 27         True
# 28        False
# 29        False
#           ...
# 104480     True
# 104481    False
# 104482     True
# 104483     True
# 104484    False
# 104485     True
# 104486     True
# 104487    False
# 104488     True
# 104489    False
# 104490     True
# 104491     True
# 104492     True
# 104493     True
# 104494     True
# 104495    False
# 104496    False
# 104497     True
# 104498     True
# 104499     True
# 104500     True
# 104501    False
# 104502     True
# 104503     True
# ...

# %%
import pandas as pd
from tqdm import tqdm
import numpy as np
from numpy import random as nr
df=pd.read_csv('C:/Users/xyttttt/Desktop/0918-2.csv',low_memory=False)
df1=pd.read_csv('C:/Users/xyttttt/Desktop/alldata/0918.csv',low_memory=False)
r,c=df.shape
for i in tqdm(range(r)):
    for j in range(1,6):
        if df1.iloc[i,j]>df.iloc[i,j]:
            df1.iloc[i,j]=df.iloc[i,j]
df1.to_csv('C:/Users/xyttttt/Desktop/confi.csv',index=False)
# Out:
# 100%|██████████| 104510/104510 [03:28<00:00, 501.65it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-b07e5b9c8041> in <module>()
#      10         if df1.iloc[i,j]>df.iloc[i,j]:
#      11             df1.iloc[i,j]=df.iloc[i,j]
# ---> 12 df1.to_csv('C:/Users/xyttttt/Desktop/confi.csv',low_memory=False)
#
# TypeError: to_csv() got an unexpected keyword argument 'low_memory'

# %%
df1.to_csv('C:/Users/xyttttt/Desktop/confi.csv',index=False)

# %%
goodsNum['week1']=(goodsNum12['9']*0.15+goodsNum12['10']*0.15+goodsNum12['11']*0.05+goodsNum12['12']*0.05+goodsNum12['13']*0.2+goodsNum12['14']*0.4)
goodsNum['week2']=goodsNum12['9']*0.15+goodsNum12['10']*0.15+goodsNum12['11']*0.05+goodsNum12['12']*0.05+goodsNum12['13']*0.2+goodsNum12['14']*0.3
goodsNum['week3']=goodsNum12['9']*0.15+goodsNum12['10']*0.15+goodsNum12['11']*0.05+goodsNum12['12']*0.05+goodsNum12['13']*0.2+goodsNum12['14']*0.3
goodsNum['week4']=goodsNum12['9']*0.15+goodsNum12['10']*0.15+goodsNum12['11']*0.05+goodsNum12['12']*0.05+goodsNum12['13']*0.2+goodsNum12['14']*0.3
goodsNum['week5']=goodsNum12['9']*0.15+goodsNum12['10']*0.15+goodsNum12['11']*0.05+goodsNum12['12']*0.05+goodsNum12['13']*0.2+goodsNum12['14']*0.3
goodsNum.to_csv('C:/Users/xyttttt/Desktop/base.csv',index = False)
goodsNum
# Out:
#           sku_id  week1  week2  week3  week4  week5
# 0       SKDtK67I   1.45   1.45   1.45   1.45   1.45
# 1       SKpLKkIS   0.30   0.15   0.15   0.15   0.15
# 2       SK2vQMpX   8.35   7.75   7.75   7.75   7.75
# 3       SKY0RuBE   2.35   2.05   2.05   2.05   2.05
# 4       SKvr2o3y   0.20   0.10   0.10   0.10   0.10
# 5       SK4VKk3b   0.50   0.35   0.35   0.35   0.35
# 6       SKDbZjmX   1.30   1.20   1.20   1.20   1.20
# 7       SK9wkGUJ   0.40   0.30   0.30   0.30   0.30
# 8       SKjQriLy   0.40   0.30   0.30   0.30   0.30
# 9       SKGy1eQD   1.85   1.55   1.55   1.55   1.55
# 10      SKd8KLXp   0.20   0.20   0.20   0.20   0.20
# 11      SK6ry4mi   0.25   0.20   0.20   0.20   0.20
# 12      SKOpvNGo   3.30   2.85   2.85   2.85   2.85
# 13      SKMF0WaA   1.00   1.00   1.00   1.00   1.00
# 14      SKdm0HJM   0.55   0.45   0.45   0.45   0.45
# 15      SKBkZXdJ   0.10   0.05   0.05   0.05   0.05
# 16      SKSbGnOU   1.20   1.10   1.10   1.10   1.10
# ...
