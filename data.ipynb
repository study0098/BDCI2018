# %%
import pandas as pd
from tqdm import tqdm
import numpy as np

info = pd.read_csv('C:/Users/xyttttt/Desktop/959.csv',low_memory=False)
info1 = pd.read_csv('C:/Users/xyttttt/Desktop/dec_test.csv',low_memory=False)
#info['ratio1']=info1['week1']/info['week1']
info
# Out:
#           sku_id      week1      week2      week3      week4      week5
# 0       SKDtK67I   1.776025   2.381795   3.062233   3.394344   1.952322
# 1       SKpLKkIS   0.398499   0.534419   0.687094   0.761612   0.438056
# 2       SK2vQMpX   8.673495  11.631871  14.954896  16.576811   9.534472
# 3       SKY0RuBE   2.076129   2.784259   3.579675   3.967904   2.282216
# 4       SKvr2o3y   0.354221   0.475040   0.610750   0.676988   0.389383
# 5       SK4VKk3b   0.319783   0.428855   0.551372   0.611170   0.351526
# 6       SKDbZjmX   1.623513   2.177265   2.799272   3.102863   1.784672
# 7       SK9wkGUJ   0.408338   0.547615   0.704059   0.780417   0.448872
# 8       SKjQriLy   0.496893   0.666375   0.856747   0.949664   0.546218
# 9       SKGy1eQD   1.899018   2.546740   3.274299   3.629410   2.087525
# 10      SKd8KLXp   0.275505   0.369475   0.475028   0.526546   0.302853
# 11      SK6ry4mi   0.309943   0.415660   0.534406   0.592365   0.340710
# ...

# %%
list1=info['ratio1'].unique()
list2=info['ratio2'].unique()
list3=info['ratio3'].unique()
list4=info['ratio4'].unique()
list5=info['ratio5'].unique()
# Out:
# array([1.10845376, 1.10845376, 1.10845376, 1.10845376, 1.10845376,
#        1.10845376, 1.10845376, 1.10845376])

# %%
for i in tqdm(range(r)):
    sea=out.iloc[i,1]
    if sea==1:
        out.iloc[i,2]=1
    elif sea==2:
        out.iloc[i,3]=1
    elif sea==3:
        out.iloc[i,4]=1
    elif sea==4:
        out.iloc[i,5]=1
    elif sea==5:
        out.iloc[i,2]=1
        out.iloc[i,3]=1
    elif sea==6:
        out.iloc[i,2]=1
        out.iloc[i,4]=1
    elif sea==10:
        out.iloc[i,4]=1
        out.iloc[i,5]=1
out
# Out:
# ...
#   4%|▍         | 16382/423452 [01:42<42:54, 158.09it/s]
# ...
# ...
# 100%|██████████| 423452/423452 [40:41<00:00, 173.42it/s]
#        goods_id  season  spring  summer  fall  winter
# 0        GBLrYn       0       0       0     0       0
# 1        G2OzvE       6       1       0     1       0
# 2        GIa1pG       0       0       0     0       0
# 3        GR7cM4       0       0       0     0       0
# 4        GRQgu3       2       0       1     0       0
# 5        Ga3Nnu       0       0       0     0       0
# 6        GUnDK6       0       0       0     0       0
# 7        GtJL8h       0       0       0     0       0
# 8        GMdFkZ       1       1       0     0       0
# 9        GgXFK4       0       0       0     0       0
# 10       Gw0iMl       2       0       1     0       0
# 11       GC5cUm       0       0       0     0       0
# 12       GYXZgl       3       0       0     1       0
# 13       G5xyvg       4       0       0     0       1
# ...

# %%
out['season_1']=0
out['season_2']=0
out['season_3']=0
out['season_4']=0
out['season_5']=0
for i in tqdm(range(r)):
    sea=out.iloc[i,1]
    if sea==1 or sea==6:
        out.iloc[i,6]=1
        out.iloc[i,7]=1
        out.iloc[i,8]=1
        out.iloc[i,9]=1
        out.iloc[i,10]=3/7
    elif sea==2:
        out.iloc[i,10]=4/7
    elif sea==5:
        out.iloc[i,6]=1
        out.iloc[i,7]=1
        out.iloc[i,8]=1
        out.iloc[i,9]=1
        out.iloc[i,10]=1
# Out:
# ...
#   8%|▊         | 35640/423452 [02:17<48:42, 132.70it/s]
# ...
# ...
# 100%|██████████| 423452/423452 [33:24<00:00, 211.24it/s]

# %%
form.to_csv('C:/Users/xyttttt/Desktop/alldata/form3.csv',index=False)

# %%
import pandas as pd
from tqdm import tqdm
import numpy as np
df = pd.read_csv('C:/Users/xyttttt/Desktop/confi.csv',low_memory=False)
df1 = pd.read_csv('C:/Users/xyttttt/Desktop/small.csv',low_memory=False)
r,c=df.shape
for i in tqdm(range(r)):
    for j in range(1,6):
        if df.iloc[i,j]>df1.iloc[i,j]:
            df.iloc[i,j]=df1.iloc[i,j]
df.to_csv('C:/Users/xyttttt/Desktop/nono.csv',index=False)
# Out:
# 100%|██████████| 104510/104510 [00:14<00:00, 7151.20it/s]

# %%
out.to_csv('C:/Users/xyttttt/Desktop/out1.csv',index=False)

# %%
import pandas as pd
from tqdm import tqdm
import numpy as np

info1 = pd.read_csv('C:/Users/xyttttt/Desktop/info.csv',low_memory=False)
info2 = pd.read_csv('C:/Users/xyttttt/Desktop/out1.csv',low_memory=False)

del info2['season_1']
del info2['season_2']
del info2['season_3']
del info2['season_4']
del info2['season_5']

info2['goods_season']=info2['season']
del info2['season']
info2
# Out:
#        goods_id  spring  summer  fall  winter  goods_season
# 0        GBLrYn       0       0     0       0             0
# 1        G2OzvE       1       0     1       0             6
# 2        GIa1pG       0       0     0       0             0
# 3        GR7cM4       0       0     0       0             0
# 4        GRQgu3       0       1     0       0             2
# 5        Ga3Nnu       0       0     0       0             0
# 6        GUnDK6       0       0     0       0             0
# 7        GtJL8h       0       0     0       0             0
# 8        GMdFkZ       1       0     0       0             1
# 9        GgXFK4       0       0     0       0             0
# 10       Gw0iMl       0       1     0       0             2
# 11       GC5cUm       0       0     0       0             0
# 12       GYXZgl       0       0     1       0             3
# 13       G5xyvg       0       0     0       1             4
# 14       GphXBq       0       0     1       0             3
# ...

# %%
info1=pd.merge(info1,info2,on='goods_id',how='left')
info1
# Out:
#        goods_id  lvl1  lvl2  same_lvl1  same_lvl2  same_lvl1_lvl2  brand_id  \
# 0        GBLrYn     2     6     123928        192             192         0
# 1        G2OzvE    35    36      23897       5687            5687        74
# 2        GIa1pG     2  6500     123928      33934           33934        55
# 3        GR7cM4    31    50      37344         13              13         0
# 4        GRQgu3     2  6500     123928      33934           33934        31
# 5        Ga3Nnu     2  6412     123928      12890           12890         0
# 6        GUnDK6     2    12     123928         37              37        12
# 7        GtJL8h     2    73     123928        422             422         0
# 8        GMdFkZ     2    14     123928       8775            8775         0
# 9        GgXFK4     2    75     123928          8               8         0
# 10       Gw0iMl     2  6500     123928      33934           33934        27
# ...

# %%
info1.to_csv('C:/Users/xyttttt/Desktop/info.csv',index=False)
