# %%
import pandas as pd
from tqdm import tqdm
import numpy as np
fit1 = pd.read_csv('C:/Users/xyttttt/Desktop/959.csv',encoding='utf8',low_memory=False)
fit2 = pd.read_csv('C:/Users/xyttttt/Desktop/sample.csv',encoding='utf8',low_memory=False)
print(1)
# Out:
# 1

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from IPython.core.pylabtools import figsize
plt.rcParams['figure.dpi'] = 300
x=range(104510)
l1=fit1.loc[fit1['week1']>=100]
l2=fit2.loc[fit2['week1']>=100]
plt.scatter(x,fit1.week1,marker='.')
plt.scatter(x,fit2.week1,marker='.')
plt.plot(l1.week1,marker='.')
plt.plot(l2.week1,marker='.')

# %%
for i in tqdm(range(104510)):
    if fit2.iloc[i,1]>=800:
        fit2.iloc[i,1]=800
        break
# Out:
#  68%|██████▊   | 71197/104510 [00:00<00:00, 141017.38it/s]

# %%
fit2.to_csv('C:/Users/xyttttt/Desktop/base.csv',index=False)
print(1)
# Out:
# 1

# %%
fit1['week1']=np.round(fit1['week1']).astype(int)
fit1['week2']=np.round(fit1['week2']).astype(int)
fit1['week3']=np.round(fit1['week3']).astype(int)
fit1['week4']=np.round(fit1['week4']).astype(int)
fit1['week5']=np.round(fit1['week5']).astype(int)
fit1.to_csv('C:/Users/xyttttt/Desktop/round.csv',index=False)
fit1
# Out:
#           sku_id  week1  week2  week3  week4  week5
# 0       SKDtK67I      2      2      3      3      2
# 1       SKpLKkIS      0      1      1      1      0
# 2       SK2vQMpX      9     12     15     17     10
# 3       SKY0RuBE      2      3      4      4      2
# 4       SKvr2o3y      0      0      1      1      0
# 5       SK4VKk3b      0      0      1      1      0
# 6       SKDbZjmX      2      2      3      3      2
# 7       SK9wkGUJ      0      1      1      1      0
# 8       SKjQriLy      0      1      1      1      1
# 9       SKGy1eQD      2      3      3      4      2
# 10      SKd8KLXp      0      0      0      1      0
# 11      SK6ry4mi      0      0      1      1      0
# 12      SKOpvNGo      3      4      5      6      3
# 13      SKMF0WaA      1      1      1      2      1
# 14      SKdm0HJM      0      0      1      1      0
# 15      SKBkZXdJ      0      0      0      0      0
# 16      SKSbGnOU      1      2      2      3      2
# ...
